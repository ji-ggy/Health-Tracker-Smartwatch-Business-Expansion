# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/My Project/dataset/state_income.csv")
df

# %%
df1 = pd.read_csv('/content/drive/MyDrive/My Project/dataset/state_income.csv')
df2 = pd.read_csv('/content/drive/MyDrive/My Project/dataset/convictions.csv')
merged_df = pd.merge(df1, df2, on='state_usa')

# %%
merged_df.columns
# Out:
# Index(['state_usa', 'average_income', 'minimum_income', 'maximum_income',
#        'convictions_per_capita'],
#       dtype='object')

# %%
print(merged_df.head())

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(merged_df['average_income'], merged_df['convictions_per_capita'], color='blue', alpha=0.7)
plt.title('State Income vs. Corruption Convictions per Capita')
plt.xlabel('Average Income')
plt.ylabel('Corruption Convictions per Capita')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Calculate the correlation coefficient between average_income and convictions_per_capita
correlation_coefficient = merged_df['average_income'].corr(merged_df['convictions_per_capita'])

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(merged_df['average_income'], merged_df['convictions_per_capita'], color='blue', alpha=0.7)
plt.title('Correlation: Income vs. Convictions')
plt.xlabel('Average Income')
plt.ylabel('Convictions Per Capita')
plt.grid(True, linestyle='--', alpha=0.7)
plt.text(0.7, 0.1, f'Correlation Coefficient: {correlation_coefficient:.2f}', transform=plt.gca().transAxes)
plt.show()

# The correlation coefficient ranges from -1 to 1, where:
#Values close to 1 indicate a strong positive correlation (as one variable increases, the other tends to increase as well).
#Values close to -1 indicate a strong negative correlation (as one variable increases, the other tends to decrease).
#Values close to 0 indicate a weak correlation or no correlation between the variables.

#a correlation coefficient of -0.23 indicates a weak negative correlation between 'average_income' and 'convictions_per_capita'.
# This means that even though these two variables are correlated, we cannot conclude that changes in 'average_income' directly cause changes in 'convictions_per_capita', or vice versa.

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Create the correlation matrix
correlation_matrix = merged_df[['average_income', 'convictions_per_capita']].corr()

# Print the correlation matrix
print(correlation_matrix)

# Create a heatmap using Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix')
plt.show()
# Out:
#                         average_income  convictions_per_capita
# average_income                1.000000               -0.226282
# convictions_per_capita       -0.226282                1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a histogram
plt.figure(figsize=(10, 6))
plt.hist(merged_df['average_income'], bins=20, color='blue', alpha=0.7)
plt.title('Income Distribution for All States')
plt.xlabel('Average Income')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()
